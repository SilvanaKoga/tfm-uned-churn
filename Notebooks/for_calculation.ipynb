# %%
cv_freight_value = 15.83685044/20.03238653
cv_freight_value
# Out:
# 0.7905623434473535

# %%
cv_payment_value = 267.7760767/172.7351352
cv_payment_value
# Out:
# 1.5502119843189839

# %%
cv_namelength_value = 10.03354018/48.76749771
cv_namelength_value
# Out:
# 0.2057423622525249

# %%
cv_descriotionlength_value = 652.5841208/785.9678219
cv_descriotionlength_value
# Out:
# 0.8302936871161495

# %%
cv_photosquant_value = 1.717451875/2.205161191
cv_photosquant_value
# Out:
# 0.7788328046083411

# %%
cv_weight_value = 3786.695111/2112.25074
cv_weight_value
# Out:
# 1.7927299251413684

# %%
cv_length_value = 16.18936729/30.26514498
cv_length_value
# Out:
# 0.5349178832844963

# %%
cv_height_value = 13.45358398/16.61970581
cv_height_value
# Out:
# 0.8094959161012971

# %%
cv_width_value = 11.74913915/23.07479922
cv_width_value
# Out:
# 0.5091762245894853
