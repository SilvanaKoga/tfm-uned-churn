# %%
import pandas as pd

import seaborn as sb
import matplotlib.pyplot as plt

# %%
DATA_PATH = "../Data"

# %%
NINETY_DAYS_T1_PATH = "churn_dataset_90_1.csv"
NINETY_DAYS_T2_PATH = "churn_dataset_90_days2.csv"
ONE_HUNDRED_TWENTY_T1_PATH = "churn_dataset_120_1.csv"
ONE_HUNDRED_TWENTY_T2_PATH = "churn_dataset_120_2.csv"
ONE_HUNDRED_FIFTY_T1_PATH = "churn_dataset_150_1.csv"
ONE_HUNDRED_FIFTY_T2_PATH = "churn_dataset_150_2.csv"
NINETY_DAYS_TESTT1_PATH = "churn_test_dataset_90.csv"
NINETY_DAYS_TESTT2_PATH ="churn_test_dataset_90_2.csv"
ONE_HUNDRED_TWENTY_TESTT1_PATH = "churn_test_dataset_120.csv"
ONE_HUNDRED_TWENTY_TESTT2_PATH = "churn_test_dataset_120_2.csv"

# %%
churn_dataset_90_days1 = pd.read_csv(DATA_PATH + "/" + NINETY_DAYS_T1_PATH) 
churn_dataset_90_days2 = pd.read_csv(DATA_PATH + "/" + NINETY_DAYS_T2_PATH)
churn_dataset_120_days1 = pd.read_csv(DATA_PATH + "/" + ONE_HUNDRED_TWENTY_T1_PATH)
churn_dataset_120_days2 = pd.read_csv(DATA_PATH + "/" + ONE_HUNDRED_TWENTY_T2_PATH)
churn_dataset_150_days1 = pd.read_csv(DATA_PATH + "/" + ONE_HUNDRED_FIFTY_T1_PATH)
churn_dataset_150_days2 = pd.read_csv(DATA_PATH + "/" + ONE_HUNDRED_FIFTY_T2_PATH)
Churn_test_dataset_90_days1 = pd.read_csv(DATA_PATH + "/" + NINETY_DAYS_TESTT1_PATH)
Churn_test_dataset_90_days2 = pd.read_csv(DATA_PATH + "/" + NINETY_DAYS_TESTT2_PATH)
Churn_test_dataset_120_days1 = pd.read_csv(DATA_PATH + "/" + ONE_HUNDRED_TWENTY_TESTT1_PATH)
Churn_test_dataset_120_days2 = pd.read_csv(DATA_PATH + "/" + ONE_HUNDRED_TWENTY_TESTT2_PATH)

# %% [markdown]
# -----
# -----

# %% [markdown]
# # Vertical union of columns

# %% [markdown]
# ## 90 days

# %%
train_90_df = pd.concat([churn_dataset_90_days1,churn_dataset_90_days2], axis= 0, ignore_index= True)

train_90_df
# Out:
#                     customer_unique_id   price  freight_to_price_ratio  \
# 0     0032c76b20340da25249092a268ce66c  128.90                0.124438
# 1     01f156677184504063bd19739f924af1  739.98                0.060569
# 2     0313291a6f4f16df04dcf819d88c38ef   95.00                0.187158
# 3     0636d30c77f0f9cfad81f1c9b58c791f  949.99                0.023127
# 4     0659f2d6cabae94afd4d009c6d0e07dc  390.00                0.177282
# ...                                ...     ...                     ...
# 8657  ffe3e199b9d0b7fb7d2d29a5b9498447  146.90                0.103472
# 8658  ffe4c3aa14d4702fb11fe5b3c4dd755c  118.90                0.154752
# 8659  ffedff0547d809c90c05c2691c51f9b7   17.90                0.811173
# 8660  ffef0ffa736c7b3d9af741611089729b  109.90                0.265423
# 8661  ffffd2657e2aad2907e67c3e9daecbeb   56.99                0.255659
#
#       payment_value  dates_diff  review_score  freight_to_weight_ratio  \
# ...

# %%
train_90_df.to_csv(r"C:\Users\Hallen\Documents\mis_cosas\silvana\master\tfm-uned-churn\Data\Train_test\train_90.csv", index=False)

# %% [markdown]
# ## 120 days

# %%
train_120_df = pd.concat([churn_dataset_120_days1,churn_dataset_120_days2], axis= 0, ignore_index= True)

train_120_df
# Out:
#                     customer_unique_id   price  freight_to_price_ratio  \
# 0     0032c76b20340da25249092a268ce66c  128.90                0.124438
# 1     01f156677184504063bd19739f924af1  739.98                0.060569
# 2     0313291a6f4f16df04dcf819d88c38ef   95.00                0.187158
# 3     0636d30c77f0f9cfad81f1c9b58c791f  949.99                0.023127
# 4     0659f2d6cabae94afd4d009c6d0e07dc  390.00                0.177282
# ...                                ...     ...                     ...
# 7795  ffe2dd1f3b0cbf0b5f35e818ec03c49b   89.99                0.230137
# 7796  ffe3e199b9d0b7fb7d2d29a5b9498447  146.90                0.103472
# 7797  ffebb6424578e7bb153322da9d65634f  629.00                0.058347
# 7798  ffedff0547d809c90c05c2691c51f9b7   17.90                0.811173
# 7799  ffff371b4d645b6ecea244b27531430a   89.90                0.250945
#
#       payment_value  dates_diff  review_score  freight_to_weight_ratio  \
# ...

# %%
train_120_df.to_csv(r"C:\Users\Hallen\Documents\mis_cosas\silvana\master\tfm-uned-churn\Data\Train_test\train_120.csv", index=False)

# %% [markdown]
# ## 110 days

# %%
train_150_df = pd.concat([churn_dataset_150_days1,churn_dataset_150_days2], axis= 0, ignore_index= True)

train_150_df
# Out:
#                      customer_unique_id    price  freight_to_price_ratio  \
# 0      00115fc7123b5310cf6d3a3aa932699e    59.99                0.268711
# 1      0032c76b20340da25249092a268ce66c   128.90                0.124438
# 2      008f3d5f45a11059239a5c452cd00006   309.90                0.086028
# 3      012e12f54f6e73b1faba89a119dab849    87.74                0.205152
# 4      01838e7d69d87bd8ff2b6ff06789adfb   126.90                0.253822
# ...                                 ...      ...                     ...
# 14367  ffedff0547d809c90c05c2691c51f9b7    17.90                0.811173
# 14368  ffef0ffa736c7b3d9af741611089729b   109.90                0.265423
# 14369  fffcf5a5ff07b0908bd4e2dbc735a684  1570.00                0.320939
# 14370  ffff371b4d645b6ecea244b27531430a    89.90                0.250945
# 14371  ffffd2657e2aad2907e67c3e9daecbeb    56.99                0.255659
#
#        payment_value  dates_diff  review_score  freight_to_weight_ratio  \
# ...

# %%
train_150_df.to_csv(r"C:\Users\Hallen\Documents\mis_cosas\silvana\master\tfm-uned-churn\Data\Train_test\train_150.csv", index=False)

# %% [markdown]
# # Test 90 days

# %%
test_90_df = pd.concat([Churn_test_dataset_90_days1,Churn_test_dataset_90_days2], axis= 0, ignore_index= True)

test_90_df
# Out:
#                      customer_unique_id   price  freight_to_price_ratio  \
# 0      00053a61a98854899e70ed204dd4bafe  382.00                0.097330
# 1      000c8bdb58a29e7115cfc257230fb21b   13.90                1.086331
# 2      000d460961d6dbfa3ec6c9f5805769e1   28.90                0.269204
# 3      0014a5a58da615f7b01a4f5e194bf5ea   88.00                0.134318
# 4      00196fdb2bf9edfc35e88ebfbcf8d781   12.90                1.093023
# ...                                 ...     ...                     ...
# 39545  ffecceca389973ef16660d58696f281e   59.90                0.214691
# 39546  ffeddf8aa7cdecf403e77b2e9a99e2ea  330.00                0.237576
# 39547  fff2ae16b99c6f3c785f0e052f2a9cfb  129.94                0.546098
# 39548  fffcc512b7dfecaffd80f13614af1d16  688.00                0.032994
# 39549  ffff5962728ec6157033ef9805bacc48  115.00                0.162522
#
#        payment_value  dates_diff  review_score  freight_to_weight_ratio  \
# ...

# %%
test_90_df.to_csv(r"C:\Users\Hallen\Documents\mis_cosas\silvana\master\tfm-uned-churn\Data\Train_test\test_90.csv", index=False)

# %% [markdown]
# # Test 120 days

# %%
test_120_df = pd.concat([Churn_test_dataset_120_days1,Churn_test_dataset_120_days2], axis= 0, ignore_index= True)

test_120_df
# Out:
#                      customer_unique_id   price  freight_to_price_ratio  \
# 0      00053a61a98854899e70ed204dd4bafe  382.00                0.097330
# 1      0005ef4cd20d2893f0d9fbd94d3c0d97  104.90                0.236988
# 2      00090324bbad0e9342388303bb71ba0a   49.95                0.274474
# 3      000c8bdb58a29e7115cfc257230fb21b   13.90                1.086331
# 4      000d460961d6dbfa3ec6c9f5805769e1   28.90                0.269204
# ...                                 ...     ...                     ...
# 39952  ffe76cb2f4bb39384c432d65ece67441   49.00                0.348163
# 39953  ffec10ad4229ba46818560e1c8b40a68  120.00                0.131000
# 39954  ffecceca389973ef16660d58696f281e   59.90                0.214691
# 39955  fff2ae16b99c6f3c785f0e052f2a9cfb  129.94                0.546098
# 39956  fffcc512b7dfecaffd80f13614af1d16  688.00                0.032994
#
#        payment_value  dates_diff  review_score  freight_to_weight_ratio  \
# ...

# %%
test_120_df.to_csv(r"C:\Users\Hallen\Documents\mis_cosas\silvana\master\tfm-uned-churn\Data\Train_test\test_120.csv", index=False)
